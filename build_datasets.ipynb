# %% [markdown]
# # Build a Datasets to read the schema

# %%
import random

import datasets

from datasets import load_from_disk

dataset = load_from_disk("schema_data")

# %%
dataset = dataset.flatten()

# %%
import json

with open("/dstc8-schema-guided-dialogue/train/schema.json", 'r') as f:
    train_schemas = json.load(f)
import json

with open("/dstc8-schema-guided-dialogue/test/schema.json", 'r') as f:
    test_schemas = json.load(f)
import json

with open("/dstc8-schema-guided-dialogue/dev/schema.json", 'r') as f:
    dev_schemas = json.load(f)
# change schema format
import collections


def schema_dict(scheme: list):
    res = collections.defaultdict(list)
    for service_dict in scheme:
        service_name = service_dict['service_name']
        assert service_name not in res, f"{service_name} is duplicated."
        res[service_name] = service_dict
    return res


test_schemas = schema_dict(test_schemas)
train_schemas = schema_dict(train_schemas)
dev_schemas = schema_dict(dev_schemas)

# %%
test_schemas.keys()
# Out:
# dict_keys(['Alarm_1', 'Buses_3', 'Events_3', 'Flights_4', 'Homes_2', 'Hotels_2', 'Hotels_4', 'Media_3', 'Messaging_1', 'Movies_1', 'Movies_3', 'Music_3', 'Payment_1', 'RentalCars_3', 'Restaurants_2', 'RideSharing_2', 'Services_1', 'Services_4', 'Trains_1', 'Travel_1', 'Weather_1'])

# %% [markdown]
# - [ ] write preprocess function for inputs

# %% [markdown]
# form dataset to input ids in this format.
# ```
# [CLS] keep | jump [SEP] utterance [SEP] Intent1 description # intent1 [SEP] Intent2 description # intent2[SEP]
# ```

# %% [markdown]
# - [x] process keep | jump
# - [x] process utterance
# - [ ] process intent description and intent

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames'],
#         num_rows: 16142
#     })
#     validation: Dataset({
#         features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames'],
#         num_rows: 2482
#     })
#     test: Dataset({
#         features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames'],
#         num_rows: 4201
#     })
# })

# %%
from transformers import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# %%
tokenizer.decode(tokenizer.encode("s", "b"))
# Out:
# '[CLS] s [SEP] b [SEP]'

# %%
sample_dataset = dataset['validation']

# %%
sample_dataset
# Out:
# Dataset({
#     features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames'],
#     num_rows: 2482
# })

# %%
tokenizer.decode(tokenizer.encode('keep', 'I want to make a restaurant reservation for 2 people at half past 11 in the morning.'))
# Out:
# '[CLS] keep [SEP] I want to make a restaurant reservation for 2 people at half past 11 in the morning. [SEP]'

# %%
def combine_sys_usr(sample):
    utterances = sample['turns.utterance']
    utterances.insert(0, "")
    start = 0
    end = 1
    res = []
    while end < len(utterances):
        combined_utt = "sys: " + utterances[start] + "usr: " + utterances[end]
        res.append(combined_utt)
        start = end + 1
        end = start + 1
    sample['new_utt'] = res
    return sample

sample_dataset = sample_dataset.map(combine_sys_usr)
# Out:
# Loading cached processed dataset at schema_data/validation/cache-914f78a7ba34973d.arrow

# %%
def keep_jump(sample):
    """Judge whether frame change or not.
    """
    SYS = 0
    USR = 1
    
    tokenized_utts = []
    last_frame = {}
    for spk, utt, frames in zip(sample['turns.speaker'], sample['new_utt'], sample['turns.frames']):
        if spk == USR:
            continue
        else:
            frames = {}
            for frame_id in frames:
                frames[frame_id] = ''
            if frames == last_frame:
                tmp_utt = ['keep', utt]
            else:
                tmp_utt = ['jump', utt]
            tokens = tokenizer.encode(tmp_utt[0], tmp_utt[1])
            tokenized_utts.append(tokens)
            last_frame = frames
    sample["utts_with_changes"] = tokenized_utts
    return sample
sample_dataset = sample_dataset.map(keep_jump)
sample_dataset
# Out:
# Loading cached processed dataset at schema_data/validation/cache-e7d4a8d6d8970d79.arrow
# Dataset({
#     features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames', 'new_utt', 'utts_with_changes'],
#     num_rows: 2482
# })

# %%
tokenizer.decode((sample_dataset['utts_with_changes'][1][2]))
# Out:
# '[CLS] keep [SEP] sys : You would like to reserve a table for 11 : 30 am for next Monday? usr : That would be fine. Is the restaurant costly? [SEP]'

# %% [markdown]
# form dataset to input ids in this format.
# ```
# [CLS] keep | jump [SEP] utterance [SEP] Intent1 description # intent1 [SEP] Intent2 description # intent2[SEP]
# ```
# 目前完成 keep，jump，以及utterance的 tokenizer，现在需要调查一下
# - [ ] intent description 和 intent 之间是怎么整合到一起的。
#     - [ ] 阅读 corpus intent 相关部分，盲猜 intent description # intent

# %% [markdown]
# 1. description 直接经过 bert tokenize 得到对应tokens。
# 2. tokenize(intent description # intent name)
# 3. tokenizer 利用的是 bert-base-cased，需要区分大小写。

# %%
tokenizer.convert_ids_to_tokens(tokenizer.encode("Make a reservation with the therapist based on user's wish # BookAppointment"))
# Out:
# ['[CLS]',
#  'Make',
#  'a',
#  'reservation',
#  'with',
#  'the',
#  'therapist',
#  'based',
#  'on',
#  'user',
#  "'",
#  's',
#  'wish',
#  '#',
#  'Book',
#  '##A',
#  '##pp',
#  '##oint',
#  '##ment',
#  '[SEP]']

# %% [markdown]
# - [ ] check the dataset, pair the intent and description.

# %%
sample_dataset['turns.frames'][0]
# Out:
# [{'service': ['Restaurants_2'],
#   'slots': [{'slot': ['time'], 'start': [56], 'exclusive_end': [83]}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['number_of_seats', 'time'],
#      'slot_value_list': [['2'], ['half past 11 in the morning']]}}],
#   'actions': [{'act': [4, 4, 6],
#     'slot': ['time', 'number_of_seats', 'intent'],
#     'canonical_values': [['11:30'], ['2'], ['ReserveRestaurant']],
#     'values': [['half past 11 in the morning'],
#      ['2'],
#      ['ReserveRestaurant']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [13, 13],
#     'slot': ['restaurant_name', 'location'],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': ['location', 'restaurant_name'],
#     'start': [27, 49],
#     'exclusive_end': [35, 53]}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['half past 11 in the morning']]}}],
#   'actions': [{'act': [4, 4],
#     'slot': ['location', 'restaurant_name'],
#     'canonical_values': [['San Jose'], ['Sino']],
#     'values': [['San Jose'], ['Sino']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': ['restaurant_name', 'location', 'time', 'date'],
#     'start': [51, 59, 93, 102],
#     'exclusive_end': [55, 67, 101, 107]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [2, 2, 2, 2, 2],
#     'slot': ['restaurant_name', 'location', 'time', 'number_of_seats', 'date'],
#     'canonical_values': [['Sino'],
#      ['San Jose'],
#      ['11:30'],
#      ['2'],
#      ['2019-03-01']],
#     'values': [['Sino'], ['San Jose'], ['11:30 am'], ['2'], ['today']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': ['phone_number'],
#     'slot_values': {'slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['today'],
#       ['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['11:30 am', 'half past 11 in the morning']]}}],
#   'actions': [{'act': [13, 0],
#     'slot': ['phone_number', ''],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': ['phone_number'], 'start': [54], 'exclusive_end': [66]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [4, 10],
#     'slot': ['phone_number', ''],
#     'canonical_values': [['408-247-8880'], []],
#     'values': [['408-247-8880'], []]}],
#   'service_results': [{'service_results_list': [{'service_slot_name': ['address',
#        'category',
#        'date',
#        'has_seating_outdoors',
#        'has_vegetarian_options',
#        'location',
#        'number_of_seats',
#        'phone_number',
#        'price_range',
#        'rating',
#        'restaurant_name',
#        'time'],
#       'service_canonical_value': ['377 Santana Row #1000',
#        'Asian',
#        '2019-03-01',
#        'True',
#        'True',
#        'San Jose',
#        '2',
#        '408-247-8880',
#        'moderate',
#        '4.00',
#        'Sino',
#        '11:30']}]}],
#   'service_call': [{'method': 'ReserveRestaurant',
#     'parameters': {'parameter_slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'parameter_canonical_value': ['2019-03-01',
#       'San Jose',
#       '2',
#       'Sino',
#       '11:30']}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': ['address', 'has_vegetarian_options'],
#     'slot_values': {'slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['today'],
#       ['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['11:30 am', 'half past 11 in the morning']]}}],
#   'actions': [{'act': [13, 13],
#     'slot': ['has_vegetarian_options', 'address'],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': ['address'], 'start': [22], 'exclusive_end': [43]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [4, 4],
#     'slot': ['has_vegetarian_options', 'address'],
#     'canonical_values': [['True'], ['377 Santana Row #1000']],
#     'values': [['True'], ['377 Santana Row #1000']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['today'],
#       ['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['11:30 am', 'half past 11 in the morning']]}}],
#   'actions': [{'act': [17],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [15],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'NONE',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['today'],
#       ['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['11:30 am', 'half past 11 in the morning']]}}],
#   'actions': [{'act': [7, 17],
#     'slot': ['', ''],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [3],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]}]

# %%
sample_dataset
# Out:
# Dataset({
#     features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames', 'new_utt', 'utts_with_changes'],
#     num_rows: 2482
# })

# %%
sample_dataset[0]['turns.frames'][1]
# Out:
# {'service': ['Restaurants_2'],
#  'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#  'state': [{'active_intent': '',
#    'requested_slots': [],
#    'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#  'actions': [{'act': [13, 13],
#    'slot': ['restaurant_name', 'location'],
#    'canonical_values': [[], []],
#    'values': [[], []]}],
#  'service_results': [{'service_results_list': []}],
#  'service_call': [{'method': '',
#    'parameters': {'parameter_slot_name': [],
#     'parameter_canonical_value': []}}]}

# %%
len(train_schemas)
# Out:
# 26

# %%
len(sample_dataset[0]['turns.frames'])
# Out:
# 12

# %%
len(sample_dataset[0]['turns.utterance'])
# Out:
# 13

# %%
sample_dataset[0]['turns.utterance']
# Out:
# ['',
#  'I want to make a restaurant reservation for 2 people at half past 11 in the morning.',
#  'What city do you want to dine in? Do you have a preferred restaurant?',
#  'Please find restaurants in San Jose. Can you try Sino?',
#  'Confirming: I will reserve a table for 2 people at Sino in San Jose. The reservation time is 11:30 am today.',
#  "Yes, thanks. What's their phone number?",
#  'Your reservation has been made. Their phone number is 408-247-8880.',
#  "What's their address? Do they have vegetarian options on their menu?",
#  'The street address is 377 Santana Row #1000. They have good vegetarian options.',
#  'Thanks very much.',
#  'Is there anything else I can help you with?',
#  "No, that's all. Thanks.",
#  'Have a great day.']

# %% [markdown]
# - [x] 找到 intents 在 dialogue 数据中的位置

# %%
# get the infos of train
for dia_id, i in enumerate(dataset['train']['dialogue_id']):
    if i == "104_00000":
        print(dia_id)
        break
# Out:
# 13083

# %%
dataset['train'][13083]['turns.frames']
# Out:
# [{'service': ['Events_1'],
#   'slots': [{'slot': ['date', 'subcategory'],
#     'start': [68, 18],
#     'exclusive_end': [85, 22]}],
#   'state': [{'active_intent': 'FindEvents',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['date', 'subcategory'],
#      'slot_value_list': [['2nd of this month'], ['Rock']]}}],
#   'actions': [{'act': [4, 4, 6],
#     'slot': ['date', 'subcategory', 'intent'],
#     'canonical_values': [['2019-03-02'], ['Rock'], ['FindEvents']],
#     'values': [['2nd of this month'], ['Rock'], ['FindEvents']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [13, 13],
#     'slot': ['category', 'city_of_event'],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': ['city_of_event'], 'start': [21], 'exclusive_end': [24]}],
#   'state': [{'active_intent': 'FindEvents',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['LAX'],
#       ['2nd of this month'],
#       ['Rock']]}}],
#   'actions': [{'act': [4, 4],
#     'slot': ['city_of_event', 'category'],
#     'canonical_values': [['Los Angeles'], ['Music']],
#     'values': [['LAX'], ['Music']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': ['event_name', 'event_location', 'date', 'time'],
#     'start': [55, 116, 88, 101],
#     'exclusive_end': [66, 124, 97, 108]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [11, 11, 11, 11, 5],
#     'slot': ['event_name', 'event_location', 'date', 'time', 'count'],
#     'canonical_values': [['Gloryhammer'],
#      ['1720(tm)'],
#      ['2019-03-02'],
#      ['20:30'],
#      ['3']],
#     'values': [['Gloryhammer'],
#      ['1720(tm)'],
#      ['March 2nd'],
#      ['8:30 pm'],
#      ['3']]}],
#   'service_results': [{'service_results_list': [{'service_slot_name': ['address_of_location',
#        'category',
#        'city_of_event',
#        'date',
#        'event_location',
#        'event_name',
#        'subcategory',
#        'time'],
#       'service_canonical_value': ['1720 East 16th Street',
#        'Music',
#        'Los Angeles',
#        '2019-03-02',
#        '1720(tm)',
#        'Gloryhammer',
#        'Rock',
#        '20:30']},
#      {'service_slot_name': ['address_of_location',
#        'category',
#        'city_of_event',
#        'date',
#        'event_location',
#        'event_name',
#        'subcategory',
#        'time'],
#       'service_canonical_value': ['1234 West 7th Street',
#        'Music',
#        'Los Angeles',
#        '2019-03-02',
#        'The Teragram Ballroom',
#        'Murder City Devils',
#        'Rock',
#        '20:30']},
#      {'service_slot_name': ['address_of_location',
#        'category',
#        'city_of_event',
#        'date',
#        'event_location',
#        'event_name',
#        'subcategory',
#        'time'],
#       'service_canonical_value': ['448 South Main Street',
#        'Music',
#        'Los Angeles',
#        '2019-03-02',
#        'Regent Theater DTLA',
#        'Starset',
#        'Rock',
#        '20:00']}]}],
#   'service_call': [{'method': 'FindEvents',
#     'parameters': {'parameter_slot_name': ['category',
#       'city_of_event',
#       'date',
#       'subcategory'],
#      'parameter_canonical_value': ['Music',
#       'Los Angeles',
#       '2019-03-02',
#       'Rock']}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'FindEvents',
#     'requested_slots': ['address_of_location'],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['LAX'],
#       ['2nd of this month', 'March 2nd'],
#       ['Rock']]}}],
#   'actions': [{'act': [13],
#     'slot': ['address_of_location'],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': ['address_of_location'],
#     'start': [17],
#     'exclusive_end': [38]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [4],
#     'slot': ['address_of_location'],
#     'canonical_values': [['1720 East 16th Street']],
#     'values': [['1720 East 16th Street']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': ['city_of_event', 'subcategory'],
#     'start': [80, 62],
#     'exclusive_end': [92, 69]}],
#   'state': [{'active_intent': 'FindEvents',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['Philadelphia'],
#       ['2nd of this month', 'March 2nd'],
#       ['Hip Hop']]}}],
#   'actions': [{'act': [4, 4, 14],
#     'slot': ['city_of_event', 'subcategory', ''],
#     'canonical_values': [['Philadelphia'], ['Hip Hop'], []],
#     'values': [['Philadelphia'], ['Hip Hop'], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': ['event_name', 'event_location', 'date', 'time'],
#     'start': [46, 100, 66, 79],
#     'exclusive_end': [54, 125, 75, 83]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [11, 11, 11, 11, 5],
#     'slot': ['event_name', 'event_location', 'date', 'time', 'count'],
#     'canonical_values': [['Blueface'],
#      ['The Fillmore Philadelphia'],
#      ['2019-03-02'],
#      ['19:00'],
#      ['2']],
#     'values': [['Blueface'],
#      ['The Fillmore Philadelphia'],
#      ['March 2nd'],
#      ['7 pm'],
#      ['2']]}],
#   'service_results': [{'service_results_list': [{'service_slot_name': ['address_of_location',
#        'category',
#        'city_of_event',
#        'date',
#        'event_location',
#        'event_name',
#        'subcategory',
#        'time'],
#       'service_canonical_value': ['29 East Allen Street',
#        'Music',
#        'Philadelphia',
#        '2019-03-02',
#        'The Fillmore Philadelphia',
#        'Blueface',
#        'Hip Hop',
#        '19:00']},
#      {'service_slot_name': ['address_of_location',
#        'category',
#        'city_of_event',
#        'date',
#        'event_location',
#        'event_name',
#        'subcategory',
#        'time'],
#       'service_canonical_value': ['29 East Allen Street',
#        'Music',
#        'Philadelphia',
#        '2019-03-02',
#        'The Fillmore Philadelphia',
#        'Nav With Killy',
#        'Hip Hop',
#        '18:00']}]}],
#   'service_call': [{'method': 'FindEvents',
#     'parameters': {'parameter_slot_name': ['category',
#       'city_of_event',
#       'date',
#       'subcategory'],
#      'parameter_canonical_value': ['Music',
#       'Philadelphia',
#       '2019-03-02',
#       'Hip Hop']}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'FindEvents',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['Philadelphia'],
#       ['2nd of this month', 'March 2nd'],
#       ['Hip Hop']]}}],
#   'actions': [{'act': [14],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': ['event_name', 'event_location', 'date', 'time'],
#     'start': [29, 78, 47, 60],
#     'exclusive_end': [43, 103, 56, 64]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [11, 11, 11, 11],
#     'slot': ['event_name', 'event_location', 'date', 'time'],
#     'canonical_values': [['Nav With Killy'],
#      ['The Fillmore Philadelphia'],
#      ['2019-03-02'],
#      ['18:00']],
#     'values': [['Nav With Killy'],
#      ['The Fillmore Philadelphia'],
#      ['March 2nd'],
#      ['6 pm']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'FindEvents',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'event_name',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['Philadelphia'],
#       ['2nd of this month', 'March 2nd'],
#       ['Nav With Killy'],
#       ['Hip Hop']]}}],
#   'actions': [{'act': [16],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [12],
#     'slot': ['intent'],
#     'canonical_values': [['BuyEventTickets']],
#     'values': [['BuyEventTickets']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Hotels_3', 'Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []},
#    {'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'SearchHotel',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['location'],
#      'slot_value_list': [['Philadelphia']]}},
#    {'active_intent': 'NONE',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'event_name',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['Philadelphia'],
#       ['2nd of this month', 'March 2nd'],
#       ['Nav With Killy'],
#       ['Hip Hop']]}}],
#   'actions': [{'act': [6],
#     'slot': ['intent'],
#     'canonical_values': [['SearchHotel']],
#     'values': [['SearchHotel']]},
#    {'act': [8], 'slot': [''], 'canonical_values': [[]], 'values': [[]]}],
#   'service_results': [{'service_results_list': []},
#    {'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}},
#    {'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Hotels_3'],
#   'slots': [{'slot': ['hotel_name', 'average_rating'],
#     'start': [28, 11],
#     'exclusive_end': [47, 14]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [11, 11],
#     'slot': ['hotel_name', 'average_rating'],
#     'canonical_values': [['Aka University City'], ['4.60']],
#     'values': [['Aka University City'], ['4.6']]}],
#   'service_results': [{'service_results_list': [{'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['4.60',
#        'Aka University City',
#        'Philadelphia',
#        '1',
#        'False',
#        '+1 215-372-9000',
#        '264',
#        'Cira Centre South, 2929 Walnut Street']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['4.00',
#        'Aloft Philadelphia Airport',
#        'Philadelphia',
#        '2',
#        'True',
#        '+1 267-298-1700',
#        '1248',
#        '4301 Island Avenue']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['4.40',
#        'Aloft Philadelphia Downtown',
#        'Philadelphia',
#        '3',
#        'True',
#        '+1 215-607-2020',
#        '396',
#        '101 North Broad Street']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['3.90',
#        'Best Western Plus Philadelphia Convention Center Hotel',
#        'Philadelphia',
#        '1',
#        'False',
#        '+1 215-398-3080',
#        '138',
#        '1225 Vine Street']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['4.00',
#        'Club Quarters Hotel, Philadelphia',
#        'Philadelphia',
#        '3',
#        'False',
#        '+1 215-282-5000',
#        '312',
#        '1628 Chestnut Street']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['4.30',
#        'Courtyard By Marriott Philadelphia City Avenue',
#        'Philadelphia',
#        '2',
#        'False',
#        '+1 215-477-0200',
#        '880',
#        '4100 Presidential Boulevard']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['4.50',
#        'Courtyard By Marriott Philadelphia South At The Navy Yard',
#        'Philadelphia',
#        '3',
#        'False',
#        '+1 215-644-9200',
#        '1536',
#        '1001 Intrepid Avenue']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['3.90',
#        'Doubletree By Hilton Hotel Philadelphia Airport',
#        'Philadelphia',
#        '2',
#        'False',
#        '+1 215-365-4150',
#        '468',
#        '4509 Island Avenue']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['4.00',
#        'Embassy Suites By Hilton Philadelphia Airport',
#        'Philadelphia',
#        '1',
#        'False',
#        '+1 215-365-4500',
#        '504',
#        '9000 Bartram Avenue']},
#      {'service_slot_name': ['average_rating',
#        'hotel_name',
#        'location',
#        'number_of_rooms',
#        'pets_welcome',
#        'phone_number',
#        'price',
#        'street_address'],
#       'service_canonical_value': ['4.10',
#        'Fairfield Inn & Suites By Marriott Philadelphia Downtown/Center City',
#        'Philadelphia',
#        '3',
#        'False',
#        '+1 800-228-2800',
#        '720',
#        '261 South 13th Street']}]}],
#   'service_call': [{'method': 'SearchHotel',
#     'parameters': {'parameter_slot_name': ['location'],
#      'parameter_canonical_value': ['Philadelphia']}}]},
#  {'service': ['Hotels_3'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'SearchHotel',
#     'requested_slots': ['pets_welcome', 'street_address'],
#     'slot_values': {'slot_name': ['location'],
#      'slot_value_list': [['Philadelphia']]}}],
#   'actions': [{'act': [13, 13],
#     'slot': ['pets_welcome', 'street_address'],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Hotels_3'],
#   'slots': [{'slot': ['street_address'],
#     'start': [44],
#     'exclusive_end': [81]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [4, 4],
#     'slot': ['street_address', 'pets_welcome'],
#     'canonical_values': [['Cira Centre South, 2929 Walnut Street'], ['False']],
#     'values': [['Cira Centre South, 2929 Walnut Street'], ['False']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Hotels_3', 'Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []},
#    {'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'SearchHotel',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['hotel_name', 'location'],
#      'slot_value_list': [['Aka University City'], ['Philadelphia']]}},
#    {'active_intent': 'BuyEventTickets',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'event_name',
#       'number_of_seats',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['Philadelphia'],
#       ['2nd of this month', 'March 2nd'],
#       ['Nav With Killy'],
#       ['3'],
#       ['Hip Hop']]}}],
#   'actions': [{'act': [16],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]},
#    {'act': [4, 6],
#     'slot': ['number_of_seats', 'intent'],
#     'canonical_values': [['3'], ['BuyEventTickets']],
#     'values': [['3'], ['BuyEventTickets']]}],
#   'service_results': [{'service_results_list': []},
#    {'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}},
#    {'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': ['event_name', 'date', 'city_of_event'],
#     'start': [38, 56, 69],
#     'exclusive_end': [52, 65, 81]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [2, 2, 2, 2],
#     'slot': ['event_name', 'number_of_seats', 'date', 'city_of_event'],
#     'canonical_values': [['Nav With Killy'],
#      ['3'],
#      ['2019-03-02'],
#      ['Philadelphia']],
#     'values': [['Nav With Killy'], ['3'], ['March 2nd'], ['Philadelphia']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'BuyEventTickets',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'event_name',
#       'number_of_seats',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['Philadelphia'],
#       ['2nd of this month', 'March 2nd'],
#       ['Nav With Killy'],
#       ['4'],
#       ['Hip Hop']]}}],
#   'actions': [{'act': [4, 7],
#     'slot': ['number_of_seats', ''],
#     'canonical_values': [['4'], []],
#     'values': [['4'], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': ['date'], 'start': [56], 'exclusive_end': [65]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [2, 2],
#     'slot': ['number_of_seats', 'date'],
#     'canonical_values': [['4'], ['2019-03-02']],
#     'values': [['4'], ['March 2nd']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'BuyEventTickets',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'event_name',
#       'number_of_seats',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['Philadelphia'],
#       ['2nd of this month', 'March 2nd'],
#       ['Nav With Killy'],
#       ['4'],
#       ['Hip Hop']]}}],
#   'actions': [{'act': [0],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [10],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': [{'service_slot_name': ['address_of_location',
#        'city_of_event',
#        'date',
#        'event_location',
#        'event_name',
#        'number_of_seats',
#        'time'],
#       'service_canonical_value': ['29 East Allen Street',
#        'Philadelphia',
#        '2019-03-02',
#        'The Fillmore Philadelphia',
#        'Nav With Killy',
#        '4',
#        '18:00']}]}],
#   'service_call': [{'method': 'BuyEventTickets',
#     'parameters': {'parameter_slot_name': ['city_of_event',
#       'date',
#       'event_name',
#       'number_of_seats'],
#      'parameter_canonical_value': ['Philadelphia',
#       '2019-03-02',
#       'Nav With Killy',
#       '4']}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'BuyEventTickets',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['category',
#       'city_of_event',
#       'date',
#       'event_name',
#       'number_of_seats',
#       'subcategory'],
#      'slot_value_list': [['Music'],
#       ['Philadelphia'],
#       ['2nd of this month', 'March 2nd'],
#       ['Nav With Killy'],
#       ['4'],
#       ['Hip Hop']]}}],
#   'actions': [{'act': [17, 3],
#     'slot': ['', ''],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Events_1'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [3],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]}]

# %%
for j in [i['state'] for i in dataset['train'][13083]['turns.frames']]:
    print(j[0]['active_intent'])
# Out:
# FindEvents
#
# FindEvents
#
# FindEvents
#
# FindEvents
#
# FindEvents
#
# FindEvents
#
# SearchHotel
#
# SearchHotel
#
# SearchHotel
#
# BuyEventTickets
#
# BuyEventTickets
#
# BuyEventTickets

# %% [markdown]
# 每一轮对话，按照 frame，service 来提取 intent，所以一轮对话可能被拆分为多个数据。

# %% [markdown]
# TODO: 判断最终需要多少数据，是 1 个 utt 对应一个 intent，还是一个 sys, utt 对应一个 intent
#
# 回答：输入的形式都是 sys， utt对，一对儿对应一个intent。

# %%
# Generate intents from frames.
def get_intents(samples):
    """Get intents from dataset.
    """
    intents = []
    for speaker, frame in zip(samples['turns.speaker'], samples['turns.frames']):
        if speaker == 0: # 0 means usr, 1 means sys
            intent = frame['state'][0]['active_intent']
            intents.append(intent)
    samples['intents'] = intents
    return samples

sample_dataset = sample_dataset.map(get_intents)
# test
sample_dataset['intents'][0]
# Out:
#   0%|          | 0/2482 [00:00<?, ?ex/s]
# ['ReserveRestaurant',
#  'ReserveRestaurant',
#  'ReserveRestaurant',
#  'ReserveRestaurant',
#  'ReserveRestaurant',
#  'NONE']

# %% [markdown]
# utterance 会比 frames 多一个，因为最开头有个空的

# %%
train_schemas['Banks_1']['description']
# Out:
# 'Manage bank accounts and transfer money'

# %%
sample_dataset[0]['turns.frames']
# Out:
# [{'service': ['Restaurants_2'],
#   'slots': [{'slot': ['time'], 'start': [56], 'exclusive_end': [83]}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['number_of_seats', 'time'],
#      'slot_value_list': [['2'], ['half past 11 in the morning']]}}],
#   'actions': [{'act': [4, 4, 6],
#     'slot': ['time', 'number_of_seats', 'intent'],
#     'canonical_values': [['11:30'], ['2'], ['ReserveRestaurant']],
#     'values': [['half past 11 in the morning'],
#      ['2'],
#      ['ReserveRestaurant']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [13, 13],
#     'slot': ['restaurant_name', 'location'],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': ['location', 'restaurant_name'],
#     'start': [27, 49],
#     'exclusive_end': [35, 53]}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['half past 11 in the morning']]}}],
#   'actions': [{'act': [4, 4],
#     'slot': ['location', 'restaurant_name'],
#     'canonical_values': [['San Jose'], ['Sino']],
#     'values': [['San Jose'], ['Sino']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': ['restaurant_name', 'location', 'time', 'date'],
#     'start': [51, 59, 93, 102],
#     'exclusive_end': [55, 67, 101, 107]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [2, 2, 2, 2, 2],
#     'slot': ['restaurant_name', 'location', 'time', 'number_of_seats', 'date'],
#     'canonical_values': [['Sino'],
#      ['San Jose'],
#      ['11:30'],
#      ['2'],
#      ['2019-03-01']],
#     'values': [['Sino'], ['San Jose'], ['11:30 am'], ['2'], ['today']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': ['phone_number'],
#     'slot_values': {'slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['today'],
#       ['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['11:30 am', 'half past 11 in the morning']]}}],
#   'actions': [{'act': [13, 0],
#     'slot': ['phone_number', ''],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': ['phone_number'], 'start': [54], 'exclusive_end': [66]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [4, 10],
#     'slot': ['phone_number', ''],
#     'canonical_values': [['408-247-8880'], []],
#     'values': [['408-247-8880'], []]}],
#   'service_results': [{'service_results_list': [{'service_slot_name': ['address',
#        'category',
#        'date',
#        'has_seating_outdoors',
#        'has_vegetarian_options',
#        'location',
#        'number_of_seats',
#        'phone_number',
#        'price_range',
#        'rating',
#        'restaurant_name',
#        'time'],
#       'service_canonical_value': ['377 Santana Row #1000',
#        'Asian',
#        '2019-03-01',
#        'True',
#        'True',
#        'San Jose',
#        '2',
#        '408-247-8880',
#        'moderate',
#        '4.00',
#        'Sino',
#        '11:30']}]}],
#   'service_call': [{'method': 'ReserveRestaurant',
#     'parameters': {'parameter_slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'parameter_canonical_value': ['2019-03-01',
#       'San Jose',
#       '2',
#       'Sino',
#       '11:30']}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': ['address', 'has_vegetarian_options'],
#     'slot_values': {'slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['today'],
#       ['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['11:30 am', 'half past 11 in the morning']]}}],
#   'actions': [{'act': [13, 13],
#     'slot': ['has_vegetarian_options', 'address'],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': ['address'], 'start': [22], 'exclusive_end': [43]}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [4, 4],
#     'slot': ['has_vegetarian_options', 'address'],
#     'canonical_values': [['True'], ['377 Santana Row #1000']],
#     'values': [['True'], ['377 Santana Row #1000']]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'ReserveRestaurant',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['today'],
#       ['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['11:30 am', 'half past 11 in the morning']]}}],
#   'actions': [{'act': [17],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [15],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': 'NONE',
#     'requested_slots': [],
#     'slot_values': {'slot_name': ['date',
#       'location',
#       'number_of_seats',
#       'restaurant_name',
#       'time'],
#      'slot_value_list': [['today'],
#       ['San Jose'],
#       ['2'],
#       ['Sino'],
#       ['11:30 am', 'half past 11 in the morning']]}}],
#   'actions': [{'act': [7, 17],
#     'slot': ['', ''],
#     'canonical_values': [[], []],
#     'values': [[], []]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]},
#  {'service': ['Restaurants_2'],
#   'slots': [{'slot': [], 'start': [], 'exclusive_end': []}],
#   'state': [{'active_intent': '',
#     'requested_slots': [],
#     'slot_values': {'slot_name': [], 'slot_value_list': []}}],
#   'actions': [{'act': [3],
#     'slot': [''],
#     'canonical_values': [[]],
#     'values': [[]]}],
#   'service_results': [{'service_results_list': []}],
#   'service_call': [{'method': '',
#     'parameters': {'parameter_slot_name': [],
#      'parameter_canonical_value': []}}]}]

# %%
sample_dataset[0]['intents']
# Out:
# ['ReserveRestaurant',
#  'ReserveRestaurant',
#  'ReserveRestaurant',
#  'ReserveRestaurant',
#  'ReserveRestaurant',
#  'NONE']

# %%
test_schemas['Restaurants_2']['intents']
# Out:
# [{'name': 'ReserveRestaurant',
#   'description': 'Make a table reservation at a restaurant',
#   'is_transactional': True,
#   'required_slots': ['restaurant_name', 'location', 'time'],
#   'optional_slots': {'number_of_seats': '2', 'date': '2019-03-01'},
#   'result_slots': ['restaurant_name',
#    'date',
#    'time',
#    'has_seating_outdoors',
#    'has_vegetarian_options',
#    'phone_number',
#    'rating',
#    'address',
#    'number_of_seats',
#    'price_range',
#    'location',
#    'category']},
#  {'name': 'FindRestaurants',
#   'description': 'Find restaurants by location and by category',
#   'is_transactional': False,
#   'required_slots': ['category', 'location'],
#   'optional_slots': {'price_range': 'dontcare',
#    'has_vegetarian_options': 'dontcare',
#    'has_seating_outdoors': 'dontcare'},
#   'result_slots': ['restaurant_name',
#    'has_seating_outdoors',
#    'has_vegetarian_options',
#    'phone_number',
#    'rating',
#    'address',
#    'price_range',
#    'location',
#    'category']}]

# %%
test_schemas['Flights_3']
# Out:
# []

# %%
test_schemas["Flights_4"]['intents']
# Out:
# [{'name': 'SearchOnewayFlight',
#   'description': 'Search for one way flights to the destination',
#   'is_transactional': False,
#   'required_slots': ['origin_airport',
#    'destination_airport',
#    'departure_date'],
#   'optional_slots': {'seating_class': 'Economy',
#    'number_of_tickets': '1',
#    'airlines': 'dontcare'},
#   'result_slots': ['number_of_tickets',
#    'seating_class',
#    'origin_airport',
#    'destination_airport',
#    'departure_date',
#    'is_nonstop',
#    'outbound_departure_time',
#    'outbound_arrival_time',
#    'price',
#    'airlines']},
#  {'name': 'SearchRoundtripFlights',
#   'description': 'Search for roundtrip flights for the trip',
#   'is_transactional': False,
#   'required_slots': ['origin_airport',
#    'destination_airport',
#    'departure_date',
#    'return_date'],
#   'optional_slots': {'seating_class': 'Economy',
#    'number_of_tickets': '1',
#    'airlines': 'dontcare'},
#   'result_slots': ['number_of_tickets',
#    'seating_class',
#    'origin_airport',
#    'destination_airport',
#    'departure_date',
#    'return_date',
#    'is_nonstop',
#    'outbound_departure_time',
#    'outbound_arrival_time',
#    'inbound_arrival_time',
#    'inbound_departure_time',
#    'price',
#    'airlines']}]

# %%
sample_dataset[492]['intents']
# Out:
# ['CheckBalance',
#  'CheckBalance',
#  'CheckBalance',
#  'TransferMoney',
#  'TransferMoney',
#  'TransferMoney',
#  'TransferMoney',
#  'TransferMoney']

# %%
sample_dataset[492]['intents_descriptions']
# Out:
# ['Get the balance of an account',
#  'Get the balance of an account',
#  'Get the balance of an account',
#  'Transfer money to another user',
#  'Transfer money to another user',
#  'Transfer money to another user',
#  'Transfer money to another user',
#  'Transfer money to another user']

# %%
# get intent description from frame and intents name.
def get_description(samples, schema):
    """Get frames' intent description from schema.

    when intent is "None", the intent description will be "none".
    """
    descriptions = []
    for frame, single_intent in zip(samples['turns.frames'], samples['intents']):
        service_name = frame['service'][0]
        service_intents = schema[service_name]['intents']
        description = 'none'
        for intent in service_intents:
            if intent == "TransferMoney":
                print(service_intents)
            if intent['name'] == single_intent:
                description = intent['description']
                break
        descriptions.append(description)
    samples['intents_descriptions'] = descriptions
    return samples

# test
from functools import partial
get_dev_descriptions = partial(get_description, schema=dev_schemas)
sample_dataset = sample_dataset.map(get_dev_descriptions, batched=False)
# Out:
#   0%|          | 0/2482 [00:00<?, ?ex/s]

# %%
# test
index = random.randint(0, 1000)
print(len(sample_dataset[index]['turns.utterance']))
print(len(sample_dataset[index]['intents']))
print(len(sample_dataset[index]['intents_descriptions']))
# Out:
# 27
# 13
# 13

# %%
# tokenize intents' description and intents.
def tokenize_intents(samples):
    all_tokens = []
    sentences = []
    for description, intent in zip(samples['intents_descriptions'], samples['intents']):
        utt = description + "#" + intent
        sentences.append(utt)
    tokens = [tokenizer.convert_ids_to_tokens(tokenizer.encode(s, add_special_tokens=False)) for s in sentences]
    print(tokens)
# test
tokenize_intents(sample_dataset[492])
# Out:
# [['Get', 'the', 'balance', 'of', 'an', 'account', '#', 'Check', '##B', '##alan', '##ce'], ['Get', 'the', 'balance', 'of', 'an', 'account', '#', 'Check', '##B', '##alan', '##ce'], ['Get', 'the', 'balance', 'of', 'an', 'account', '#', 'Check', '##B', '##alan', '##ce'], ['Transfer', 'money', 'to', 'another', 'user', '#', 'Transfer', '##M', '##oney'], ['Transfer', 'money', 'to', 'another', 'user', '#', 'Transfer', '##M', '##oney'], ['Transfer', 'money', 'to', 'another', 'user', '#', 'Transfer', '##M', '##oney'], ['Transfer', 'money', 'to', 'another', 'user', '#', 'Transfer', '##M', '##oney'], ['Transfer', 'money', 'to', 'another', 'user', '#', 'Transfer', '##M', '##oney']]

# %% [markdown]
# TODO：判断每一条数据的 intents 是随着对话增多的，还是每个数据对应一个
#
# 1. 每个 utt 只对应一个 frame 的 intents，并且不会随着对话增多变动。
#
# TODO：一个utt怎么找到对应的 intent？

# %% [markdown]
# TODO: flatten 整个数据集。

# %%
pd_dataset = dataset.set_format('pd')

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames'],
#         num_rows: 16142
#     })
#     validation: Dataset({
#         features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames'],
#         num_rows: 2482
#     })
#     test: Dataset({
#         features: ['dialogue_id', 'services', 'turns.speaker', 'turns.utterance', 'turns.frames'],
#         num_rows: 4201
#     })
# })

# %%
frames = dataset['train']['turns.frames']
utterances = dataset['train']['turns.utterance']
speaker = dataset['train']['turns.speaker']

# %%
import pandas as pd

# %%
frames.values
# Out:
# array([array([{'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'FindRestaurants', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([6]), 'slot': array(['intent'], dtype=object), 'canonical_values': array([array(['FindRestaurants'], dtype=object)], dtype=object), 'values': array([array(['FindRestaurants'], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([13]), 'slot': array(['city'], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['city'], dtype=object), 'start': array([29], dtype=int32), 'exclusive_end': array([37], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'FindRestaurants', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['city'], dtype=object), 'slot_value_list': array([array(['San Jose'], dtype=object)], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([4]), 'slot': array(['city'], dtype=object), 'canonical_values': array([array(['San Jose'], dtype=object)], dtype=object), 'values': array([array(['San Jose'], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['cuisine', 'cuisine'], dtype=object), 'start': array([52, 61], dtype=int32), 'exclusive_end': array([59, 68], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([13]), 'slot': array(['cuisine'], dtype=object), 'canonical_values': array([array(['Mexican', 'Italian'], dtype=object)], dtype=object), 'values': array([array(['Mexican', 'Italian'], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['cuisine'], dtype=object), 'start': array([26], dtype=int32), 'exclusive_end': array([34], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'FindRestaurants', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine'], dtype=object), 'slot_value_list': array([array(['San Jose'], dtype=object),
#                             array(['American'], dtype=object)], dtype=object)}}                                                                                                                                                          ],
#                     dtype=object), 'actions': array([{'act': array([4]), 'slot': array(['cuisine'], dtype=object), 'canonical_values': array([array(['American'], dtype=object)], dtype=object), 'values': array([array(['American'], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['restaurant_name', 'city'], dtype=object), 'start': array([14, 68], dtype=int32), 'exclusive_end': array([28, 76], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([11, 11]), 'slot': array(['restaurant_name', 'city'], dtype=object), 'canonical_values': array([array(['71 Saint Peter'], dtype=object),
#                             array(['San Jose'], dtype=object)], dtype=object), 'values': array([array(['71 Saint Peter'], dtype=object),
#                             array(['San Jose'], dtype=object)], dtype=object)}                                                                                             ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([{'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-971-8523', 'moderate',
#                                    '71 Saint Peter', 'True', '71 North San Pedro Street'],
#                                   dtype=object)}                                                                                               ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-261-5787', 'moderate',
#                                    'Bazille', 'True', '2400 Forest Avenue'], dtype=object)}                                                    ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-292-4300', 'moderate',
#                                    "Billy Berk's", 'True', '99 South 1st Street'], dtype=object)}                                              ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-343-7230', 'moderate',
#                                    "Bj's Restaurant & Brewhouse", 'True', '511 Coleman Avenue'],
#                                   dtype=object)}                                                                                               ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-816-7251', 'expensive',
#                                    'Black Sheep Brasserie', 'True', '1202 Lincoln Avenue'],
#                                   dtype=object)}                                                                                                ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-238-9110', 'moderate',
#                                    "Chuck E. Cheese's", 'False', '2445 Fontaine Road'], dtype=object)}                                         ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-292-7444', 'moderate',
#                                    "Famous Dave's Bar-b-que", 'False', '61 Curtner Avenue'],
#                                   dtype=object)}                                                                                               ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-287-6969', 'moderate',
#                                    'Firehouse No.1 Gastropub', 'True', '69 North San Pedro Street'],
#                                   dtype=object)}                                                                                               ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'True', '408-279-4888', 'moderate',
#                                    'Hukilau', 'True', '230 Jackson Street'], dtype=object)}                                                   ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['San Jose', 'American', 'False', '408-998-1440', 'moderate',
#                                    "John's Of Willow Glen", 'False', '1238 Lincoln Avenue'],
#                                   dtype=object)}                                                                                               ],
#                            dtype=object)}                                                                                                            ],
#                     dtype=object), 'service_call': array([{'method': 'FindRestaurants', 'parameters': {'parameter_slot_name': array(['city', 'cuisine'], dtype=object), 'parameter_canonical_value': array(['San Jose', 'American'], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                    ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'FindRestaurants', 'requested_slots': array(['street_address'], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine'], dtype=object), 'slot_value_list': array([array(['San Jose'], dtype=object),
#                             array(['American'], dtype=object)], dtype=object)}}                                                                                                                                                                          ],
#                     dtype=object), 'actions': array([{'act': array([13]), 'slot': array(['street_address'], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['street_address'], dtype=object), 'start': array([56], dtype=int32), 'exclusive_end': array([81], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([4]), 'slot': array(['street_address'], dtype=object), 'canonical_values': array([array(['71 North San Pedro Street'], dtype=object)], dtype=object), 'values': array([array(['71 North San Pedro Street'], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                             ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'FindRestaurants', 'requested_slots': array(['phone_number'], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine'], dtype=object), 'slot_value_list': array([array(['San Jose'], dtype=object),
#                             array(['American'], dtype=object)], dtype=object)}}                                                                                                                                                                        ],
#                     dtype=object), 'actions': array([{'act': array([13]), 'slot': array(['phone_number'], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['phone_number'], dtype=object), 'start': array([37], dtype=int32), 'exclusive_end': array([49], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([4]), 'slot': array(['phone_number'], dtype=object), 'canonical_values': array([array(['408-971-8523'], dtype=object)], dtype=object), 'values': array([array(['408-971-8523'], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'FindRestaurants', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine'], dtype=object), 'slot_value_list': array([array(['San Jose'], dtype=object),
#                             array(['American'], dtype=object)], dtype=object)}}                                                                                                                                                          ],
#                     dtype=object), 'actions': array([{'act': array([14]), 'slot': array([''], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['restaurant_name', 'city'], dtype=object), 'start': array([19, 59], dtype=int32), 'exclusive_end': array([26, 67], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([11, 11]), 'slot': array(['restaurant_name', 'city'], dtype=object), 'canonical_values': array([array(['Bazille'], dtype=object),
#                             array(['San Jose'], dtype=object)], dtype=object), 'values': array([array(['Bazille'], dtype=object),
#                             array(['San Jose'], dtype=object)], dtype=object)}                                                                                      ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['city'], dtype=object), 'start': array([113], dtype=int32), 'exclusive_end': array([122], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'FindRestaurants', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine', 'price_range'], dtype=object), 'slot_value_list': array([array(['Palo Alto'], dtype=object),
#                             array(['American'], dtype=object),
#                             array(['moderate'], dtype=object)], dtype=object)}}                                                                                                                                                                          ],
#                     dtype=object), 'actions': array([{'act': array([ 4,  4, 14]), 'slot': array(['price_range', 'city', ''], dtype=object), 'canonical_values': array([array(['moderate'], dtype=object),
#                             array(['Palo Alto'], dtype=object), array([], dtype=object)],
#                            dtype=object), 'values': array([array(['moderate'], dtype=object),
#                             array(['Palo Alto'], dtype=object), array([], dtype=object)],
#                            dtype=object)}                                                                                                                                ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['restaurant_name', 'city'], dtype=object), 'start': array([ 53, 107], dtype=int32), 'exclusive_end': array([ 61, 116], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([11, 11,  5]), 'slot': array(['restaurant_name', 'city', 'count'], dtype=object), 'canonical_values': array([array(['Bird Dog'], dtype=object),
#                             array(['Palo Alto'], dtype=object), array(['7'], dtype=object)],
#                            dtype=object), 'values': array([array(['Bird Dog'], dtype=object),
#                             array(['Palo Alto'], dtype=object), array(['7'], dtype=object)],
#                            dtype=object)}                                                                                                                                         ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([{'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['Palo Alto', 'American', 'False', '650-688-2614', 'moderate',
#                                    'Bazille', 'True', '550 Stanford Shopping Center'], dtype=object)}                                           ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['Palo Alto', 'American', 'False', '650-656-8180', 'moderate',
#                                    'Bird Dog', 'False', '420 Ramona Street'], dtype=object)}                                                    ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['Palo Alto', 'American', 'False', '650-327-0284', 'moderate',
#                                    'Bistro Elan', 'False', '2363 Birch Street'], dtype=object)}                                                 ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['Palo Alto', 'American', 'False', '650-326-8640', 'moderate',
#                                    'Cafe Brioche', 'True', '445 California Avenue'], dtype=object)}                                             ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['Palo Alto', 'American', 'False', '650-493-6787', 'moderate',
#                                    'Cibo Restaurant & Bar', 'False', '3398 El Camino Real'],
#                                   dtype=object)}                                                                                                ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['Palo Alto', 'American', 'False', '650-322-7509', 'moderate',
#                                    'Local Union 271', 'False', '271 University Avenue'], dtype=object)}                                         ,
#                             {'service_slot_name': array(['city', 'cuisine', 'has_live_music', 'phone_number', 'price_range',
#                                    'restaurant_name', 'serves_alcohol', 'street_address'],
#                                   dtype=object), 'service_canonical_value': array(['Palo Alto', 'American', 'False', '650-321-3514', 'moderate',
#                                    'Palo Alto Grill', 'True', '140 University Avenue'], dtype=object)}                                          ],
#                            dtype=object)}                                                                                                            ],
#                     dtype=object), 'service_call': array([{'method': 'FindRestaurants', 'parameters': {'parameter_slot_name': array(['city', 'cuisine', 'price_range'], dtype=object), 'parameter_canonical_value': array(['Palo Alto', 'American', 'moderate'], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'ReserveRestaurant', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine', 'price_range', 'restaurant_name'], dtype=object), 'slot_value_list': array([array(['Palo Alto'], dtype=object),
#                             array(['American'], dtype=object),
#                             array(['moderate'], dtype=object),
#                             array(['Bird Dog'], dtype=object)], dtype=object)}}                                                                                                                                                                                               ],
#                     dtype=object), 'actions': array([{'act': array([ 6, 16]), 'slot': array(['intent', ''], dtype=object), 'canonical_values': array([array(['ReserveRestaurant'], dtype=object),
#                             array([], dtype=object)], dtype=object), 'values': array([array(['ReserveRestaurant'], dtype=object),
#                             array([], dtype=object)], dtype=object)}                                                                                             ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                          ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([13]), 'slot': array(['time'], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['time'], dtype=object), 'start': array([26], dtype=int32), 'exclusive_end': array([34], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'ReserveRestaurant', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine', 'price_range', 'restaurant_name', 'time'],
#                            dtype=object), 'slot_value_list': array([array(['Palo Alto'], dtype=object),
#                             array(['American'], dtype=object),
#                             array(['moderate'], dtype=object),
#                             array(['Bird Dog'], dtype=object),
#                             array(['11:30 am'], dtype=object)], dtype=object)}}                                                                                                                          ],
#                     dtype=object), 'actions': array([{'act': array([4]), 'slot': array(['time'], dtype=object), 'canonical_values': array([array(['11:30'], dtype=object)], dtype=object), 'values': array([array(['11:30 am'], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['restaurant_name', 'city', 'time', 'date'], dtype=object), 'start': array([ 78, 101,  62, 115], dtype=int32), 'exclusive_end': array([ 86, 110,  70, 120], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([2, 2, 2, 2, 2]), 'slot': array(['restaurant_name', 'city', 'time', 'party_size', 'date'],
#                            dtype=object), 'canonical_values': array([array(['Bird Dog'], dtype=object),
#                             array(['Palo Alto'], dtype=object), array(['11:30'], dtype=object),
#                             array(['2'], dtype=object), array(['2019-03-01'], dtype=object)],
#                            dtype=object), 'values': array([array(['Bird Dog'], dtype=object),
#                             array(['Palo Alto'], dtype=object),
#                             array(['11:30 am'], dtype=object), array(['2'], dtype=object),
#                             array(['today'], dtype=object)], dtype=object)}                                                  ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'ReserveRestaurant', 'requested_slots': array(['has_live_music'], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine', 'date', 'party_size', 'price_range',
#                             'restaurant_name', 'time'], dtype=object), 'slot_value_list': array([array(['Palo Alto'], dtype=object),
#                             array(['American'], dtype=object), array(['today'], dtype=object),
#                             array(['2'], dtype=object), array(['moderate'], dtype=object),
#                             array(['Bird Dog'], dtype=object),
#                             array(['11:30 am'], dtype=object)], dtype=object)}}                                                                                                                                    ],
#                     dtype=object), 'actions': array([{'act': array([13,  0]), 'slot': array(['has_live_music', ''], dtype=object), 'canonical_values': array([array([], dtype=object), array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object), array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                                  ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([ 4, 10]), 'slot': array(['has_live_music', ''], dtype=object), 'canonical_values': array([array(['False'], dtype=object), array([], dtype=object)],
#                            dtype=object), 'values': array([array(['False'], dtype=object), array([], dtype=object)],
#                            dtype=object)}                                                                                                                                              ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([{'service_slot_name': array(['city', 'cuisine', 'date', 'has_live_music', 'party_size',
#                                    'phone_number', 'price_range', 'restaurant_name', 'serves_alcohol',
#                                    'street_address', 'time'], dtype=object), 'service_canonical_value': array(['Palo Alto', 'American', '2019-03-01', 'False', '2',
#                                    '650-656-8180', 'moderate', 'Bird Dog', 'False',
#                                    '420 Ramona Street', '11:30'], dtype=object)}                                                                                   ],
#                            dtype=object)}                                                                                                                            ],
#                     dtype=object), 'service_call': array([{'method': 'ReserveRestaurant', 'parameters': {'parameter_slot_name': array(['city', 'date', 'party_size', 'restaurant_name', 'time'],
#                            dtype=object), 'parameter_canonical_value': array(['Palo Alto', '2019-03-01', '2', 'Bird Dog', '11:30'], dtype=object)}}        ],
#                     dtype=object)}                                                                                                                                                                                       ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'ReserveRestaurant', 'requested_slots': array(['serves_alcohol', 'street_address'], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine', 'date', 'party_size', 'price_range',
#                             'restaurant_name', 'time'], dtype=object), 'slot_value_list': array([array(['Palo Alto'], dtype=object),
#                             array(['American'], dtype=object), array(['today'], dtype=object),
#                             array(['2'], dtype=object), array(['moderate'], dtype=object),
#                             array(['Bird Dog'], dtype=object),
#                             array(['11:30 am'], dtype=object)], dtype=object)}}                                                                                                                                                      ],
#                     dtype=object), 'actions': array([{'act': array([13, 13]), 'slot': array(['serves_alcohol', 'street_address'], dtype=object), 'canonical_values': array([array([], dtype=object), array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object), array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                                                ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array(['street_address'], dtype=object), 'start': array([29], dtype=int32), 'exclusive_end': array([46], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([4, 4]), 'slot': array(['street_address', 'serves_alcohol'], dtype=object), 'canonical_values': array([array(['420 Ramona Street'], dtype=object),
#                             array(['False'], dtype=object)], dtype=object), 'values': array([array(['420 Ramona Street'], dtype=object),
#                             array(['False'], dtype=object)], dtype=object)}                                                                                                          ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'ReserveRestaurant', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['city', 'cuisine', 'date', 'party_size', 'price_range',
#                             'restaurant_name', 'time'], dtype=object), 'slot_value_list': array([array(['Palo Alto'], dtype=object),
#                             array(['American'], dtype=object), array(['today'], dtype=object),
#                             array(['2'], dtype=object), array(['moderate'], dtype=object),
#                             array(['Bird Dog'], dtype=object),
#                             array(['11:30 am'], dtype=object)], dtype=object)}}                                                                                                                    ],
#                     dtype=object), 'actions': array([{'act': array([17,  3]), 'slot': array(['', ''], dtype=object), 'canonical_values': array([array([], dtype=object), array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object), array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                    ,
#               {'service': array(['Restaurants_1'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([3]), 'slot': array([''], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ],
# ...
#                     dtype=object), 'state': array([{'active_intent': 'GetRide', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['destination', 'number_of_seats', 'ride_type'], dtype=object), 'slot_value_list': array([array(['200 C street'], dtype=object), array(['2'], dtype=object),
#                             array(['Luxury'], dtype=object)], dtype=object)}}                                                                                                                                                                                                                ],
#                     dtype=object), 'actions': array([{'act': array([4, 4]), 'slot': array(['ride_type', 'number_of_seats'], dtype=object), 'canonical_values': array([array(['Luxury'], dtype=object), array(['2'], dtype=object)],
#                            dtype=object), 'values': array([array(['Luxury'], dtype=object), array(['2'], dtype=object)],
#                            dtype=object)}                                                                                                                                                          ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                                         ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array(['destination'], dtype=object), 'start': array([59], dtype=int32), 'exclusive_end': array([71], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([2, 2, 2]), 'slot': array(['destination', 'number_of_seats', 'ride_type'], dtype=object), 'canonical_values': array([array(['200 C Street'], dtype=object), array(['2'], dtype=object),
#                             array(['Luxury'], dtype=object)], dtype=object), 'values': array([array(['200 C Street'], dtype=object), array(['2'], dtype=object),
#                             array(['Luxury'], dtype=object)], dtype=object)}                                                                                                                                              ],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'GetRide', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['destination', 'number_of_seats', 'ride_type'], dtype=object), 'slot_value_list': array([array(['200 C Street', '200 C street'], dtype=object),
#                             array(['2'], dtype=object), array(['Luxury'], dtype=object)],
#                            dtype=object)}}                                                                                                                                                                                                                                       ],
#                     dtype=object), 'actions': array([{'act': array([0]), 'slot': array([''], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                             ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([10]), 'slot': array([''], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([{'service_slot_name': array(['destination', 'number_of_seats', 'ride_fare', 'ride_type',
#                                    'wait_time'], dtype=object), 'service_canonical_value': array(['200 C Street', '2', '31.40', 'Luxury', '14'], dtype=object)}],
#                            dtype=object)}                                                                                                                        ],
#                     dtype=object), 'service_call': array([{'method': 'GetRide', 'parameters': {'parameter_slot_name': array(['destination', 'number_of_seats', 'ride_type'], dtype=object), 'parameter_canonical_value': array(['200 C Street', '2', 'Luxury'], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                               ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'GetRide', 'requested_slots': array(['ride_fare'], dtype=object), 'slot_values': {'slot_name': array(['destination', 'number_of_seats', 'ride_type'], dtype=object), 'slot_value_list': array([array(['200 C Street', '200 C street'], dtype=object),
#                             array(['2'], dtype=object), array(['Luxury'], dtype=object)],
#                            dtype=object)}}                                                                                                                                                                                                                                                  ],
#                     dtype=object), 'actions': array([{'act': array([13]), 'slot': array(['ride_fare'], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                                        ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array(['ride_fare'], dtype=object), 'start': array([9], dtype=int32), 'exclusive_end': array([15], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([4]), 'slot': array(['ride_fare'], dtype=object), 'canonical_values': array([array(['31.40'], dtype=object)], dtype=object), 'values': array([array(['$31.40'], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'GetRide', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['destination', 'number_of_seats', 'ride_type'], dtype=object), 'slot_value_list': array([array(['200 C Street', '200 C street'], dtype=object),
#                             array(['2'], dtype=object), array(['Luxury'], dtype=object)],
#                            dtype=object)}}                                                                                                                                                                                                                                       ],
#                     dtype=object), 'actions': array([{'act': array([17]), 'slot': array([''], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                             ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([15]), 'slot': array([''], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': 'NONE', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array(['destination', 'number_of_seats', 'ride_type'], dtype=object), 'slot_value_list': array([array(['200 C Street', '200 C street'], dtype=object),
#                             array(['2'], dtype=object), array(['Luxury'], dtype=object)],
#                            dtype=object)}}                                                                                                                                                                                                                                    ],
#                     dtype=object), 'actions': array([{'act': array([ 7, 17]), 'slot': array(['', ''], dtype=object), 'canonical_values': array([array([], dtype=object), array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object), array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                                          ,
#               {'service': array(['RideSharing_2'], dtype=object), 'slots': array([{'slot': array([], dtype=object), 'start': array([], dtype=int32), 'exclusive_end': array([], dtype=int32)}],
#                     dtype=object), 'state': array([{'active_intent': '', 'requested_slots': array([], dtype=object), 'slot_values': {'slot_name': array([], dtype=object), 'slot_value_list': array([], dtype=object)}}],
#                     dtype=object), 'actions': array([{'act': array([3]), 'slot': array([''], dtype=object), 'canonical_values': array([array([], dtype=object)], dtype=object), 'values': array([array([], dtype=object)], dtype=object)}],
#                     dtype=object), 'service_results': array([{'service_results_list': array([], dtype=object)}], dtype=object), 'service_call': array([{'method': '', 'parameters': {'parameter_slot_name': array([], dtype=object), 'parameter_canonical_value': array([], dtype=object)}}],
#                     dtype=object)}                                                                                                                                                                                                                                                           ],
#              dtype=object)                                                                                                                                                                                                                                                                                                     ],
#       dtype=object)

# %%
for v in frames:
    print(v)
